# %% [markdown]
# ## MLflow with Optuna: Hyperparameter Optimization and Tracking
#
# A critical part of building production-grade models is ensuring that a given model's parameters are selected to create the best inference set possible. However, the sheer number of combinations and their resultant metrics can become overwhelming to track manually. That's where tools like MLflow and Optuna come into play.
#
# ### Objective:
# In this notebook, you'll learn how to integrate MLflow with Optuna for hyperparameter optimization. We'll guide you through the process of:
#
# * Setting up your environment with MLflow tracking.
# * Generating our training and evaluation data sets.
# * Defining a partial function that fits a machine learning model.
# * Using Optuna for hyperparameter tuning.
# * Leveraging child runs within MLflow to keep track of each iteration during the hyperparameter tuning process.
#
# ### Why Optuna?
# Optuna is an open-source hyperparameter optimization framework in Python. It provides an efficient approach to searching over hyperparameters, incorporating the latest research and techniques. With its integration into MLflow, every trial can be systematically recorded.
#
# ### Child Runs in MLflow:
# One of the core features we will be emphasizing is the concept of 'child runs' in MLflow. When performing hyperparameter tuning, each iteration (or trial) in Optuna can be considered a 'child run'. This allows us to group all the runs under one primary 'parent run', ensuring that the MLflow UI remains organized and interpretable. Each child run will track the specific hyperparameters used and the resulting metrics, providing a consolidated view of the entire optimization process.
#
# ### What's Ahead?
#
# **Data Preparation**: We'll start by loading and preprocessing our dataset.
#
# **Model Definition**: Defining a machine learning model that we aim to optimize.
#
# **Optuna Study**: Setting up an Optuna study to find the best hyperparameters for our model.
#
# **MLflow Integration**: Tracking each Optuna trial as a child run in MLflow.
#
# **Analysis**: Reviewing the tracked results in the MLflow UI.
#
# By the end of this notebook, you'll have hands-on experience in setting up an advanced hyperparameter tuning workflow, emphasizing best practices and clean organization using MLflow and Optuna.
#
# **Let's dive in!**

# %%
import math
from datetime import datetime, timedelta

import numpy as np
import optuna
import pandas as pd
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow

# %% [markdown]
# ### Configure the tracking server uri
#
# Depending on where you are running this notebook, your configuration may vary for how you initialize the interface with the MLflow Tracking Server.
#
# For this example, we're using a locally running tracking server, but other options are available (The easiest is to use the free managed service within [Databricks Community Edition](https://community.cloud.databricks.com/)).
#
# Please see [the guide to running notebooks here](https://www.mlflow.org/docs/latest/getting-started/running-notebooks/index.html) for more information on setting the tracking server uri and configuring access to either managed or self-managed MLflow tracking servers.

# %%
# NOTE: review the links mentioned above for guidance on connecting to a managed tracking server, such as the free Databricks Community Edition

mlflow.set_tracking_uri("http://localhost:5000")

# %% [markdown]
# ### Generate our synthetic training data
#
# If you've followed along with the introductory tutorial "Logging your first model with MLflow", then you're familiar with the apples sales data generator that we created for that tutorial.
#
# Here, we're expanding upon the data to create a slightly more complex dataset that should have improved correlation effects between the features and the target variable (the demand).

# %%
def generate_apple_sales_data_with_promo_adjustment(
    base_demand: int = 1000,
    n_rows: int = 5000,
    competitor_price_effect: float = -50.0,
):
    """
    Generates a synthetic dataset for predicting apple sales demand with multiple
    influencing factors.

    This function creates a pandas DataFrame with features relevant to apple sales.
    The features include date, average_temperature, rainfall, weekend flag, holiday flag,
    promotional flag, price_per_kg, competitor's price, marketing intensity, stock availability,
    and the previous day's demand. The target variable, 'demand', is generated based on a
    combination of these features with some added noise.

    Args:
        base_demand (int, optional): Base demand for apples. Defaults to 1000.
        n_rows (int, optional): Number of rows (days) of data to generate. Defaults to 5000.
        competitor_price_effect (float, optional): Effect of competitor's price being lower
                                                   on our sales. Defaults to -50.

    Returns:
        pd.DataFrame: DataFrame with features and target variable for apple sales prediction.

    Example:
        >>> df = generate_apple_sales_data_with_promo_adjustment(base_demand=1200, n_rows=6000)
        >>> df.head()
    """

    # Set seed for reproducibility
    np.random.seed(9999)

    # Create date range
    dates = [datetime.now() - timedelta(days=i) for i in range(n_rows)]
    dates.reverse()

    # Generate features
    df = pd.DataFrame(
        {
            "date": dates,
            "average_temperature": np.random.uniform(10, 35, n_rows),
            "rainfall": np.random.exponential(5, n_rows),
            "weekend": [(date.weekday() >= 5) * 1 for date in dates],
            "holiday": np.random.choice([0, 1], n_rows, p=[0.97, 0.03]),
            "price_per_kg": np.random.uniform(0.5, 3, n_rows),
            "month": [date.month for date in dates],
        }
    )

    # Introduce inflation over time (years)
    df["inflation_multiplier"] = 1 + (df["date"].dt.year - df["date"].dt.year.min()) * 0.03

    # Incorporate seasonality due to apple harvests
    df["harvest_effect"] = np.sin(2 * np.pi * (df["month"] - 3) / 12) + np.sin(
        2 * np.pi * (df["month"] - 9) / 12
    )

    # Modify the price_per_kg based on harvest effect
    df["price_per_kg"] = df["price_per_kg"] - df["harvest_effect"] * 0.5

    # Adjust promo periods to coincide with periods lagging peak harvest by 1 month
    peak_months = [4, 10]  # months following the peak availability
    df["promo"] = np.where(
        df["month"].isin(peak_months),
        1,
        np.random.choice([0, 1], n_rows, p=[0.85, 0.15]),
    )

    # Generate target variable based on features
    base_price_effect = -df["price_per_kg"] * 50
    seasonality_effect = df["harvest_effect"] * 50
    promo_effect = df["promo"] * 200

    df["demand"] = (
        base_demand
        + base_price_effect
        + seasonality_effect
        + promo_effect
        + df["weekend"] * 300
        + np.random.normal(0, 50, n_rows)
    ) * df["inflation_multiplier"]  # adding random noise

    # Add previous day's demand
    df["previous_days_demand"] = df["demand"].shift(1)
    df["previous_days_demand"].fillna(method="bfill", inplace=True)  # fill the first row

    # Introduce competitor pricing
    df["competitor_price_per_kg"] = np.random.uniform(0.5, 3, n_rows)
    df["competitor_price_effect"] = (
        df["competitor_price_per_kg"] < df["price_per_kg"]
    ) * competitor_price_effect

    # Stock availability based on past sales price (3 days lag with logarithmic decay)
    log_decay = -np.log(df["price_per_kg"].shift(3) + 1) + 2
    df["stock_available"] = np.clip(log_decay, 0.7, 1)

    # Marketing intensity based on stock availability
    # Identify where stock is above threshold
    high_stock_indices = df[df["stock_available"] > 0.95].index

    # For each high stock day, increase marketing intensity for the next week
    for idx in high_stock_indices:
        df.loc[idx : min(idx + 7, n_rows - 1), "marketing_intensity"] = np.random.uniform(0.7, 1)

    # If the marketing_intensity column already has values, this will preserve them;
    #  if not, it sets default values
    fill_values = pd.Series(np.random.uniform(0, 0.5, n_rows), index=df.index)
    df["marketing_intensity"].fillna(fill_values, inplace=True)

    # Adjust demand with new factors
    df["demand"] = df["demand"] + df["competitor_price_effect"] + df["marketing_intensity"]

    # Drop temporary columns
    df.drop(
        columns=[
            "inflation_multiplier",
            "harvest_effect",
            "month",
            "competitor_price_effect",
            "stock_available",
        ],
        inplace=True,
    )

    return df

# %%
df = generate_apple_sales_data_with_promo_adjustment(base_demand=1_000, n_rows=5000)
df
# Out:
# /tmp/ipykernel_128080/1129670120.py:85: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["previous_days_demand"].fillna(method="bfill", inplace=True)  # fill the first row
# /tmp/ipykernel_128080/1129670120.py:85: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["previous_days_demand"].fillna(method="bfill", inplace=True)  # fill the first row
# /tmp/ipykernel_128080/1129670120.py:108: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["marketing_intensity"].fillna(fill_values, inplace=True)
#                            date  average_temperature   rainfall  weekend  \
# 0    2011-03-15 19:14:17.796487            30.584727   1.199291        0
# 1    2011-03-16 19:14:17.796486            15.465069   1.037626        0
# 2    2011-03-17 19:14:17.796486            10.786525   5.656089        0
# 3    2011-03-18 19:14:17.796485            23.648154  12.030937        0
# 4    2011-03-19 19:14:17.796484            13.861391   4.303812        1
# ...                         ...                  ...        ...      ...
# 4995 2024-11-16 19:14:17.793289            21.643051   3.821656        1
# 4996 2024-11-17 19:14:17.793288            13.808813   1.080603        1
# 4997 2024-11-18 19:14:17.793288            11.698227   1.911000        0
# 4998 2024-11-19 19:14:17.793286            18.052081   1.000521        0
# 4999 2024-11-20 19:14:17.793282            17.017294   0.650213        0
#
#       holiday  price_per_kg  promo       demand  previous_days_demand  \
# 0           0      1.726258      0   851.375336            851.276659
# 1           0      0.576471      0   906.855943            851.276659
# 2           0      2.513328      0   808.304909            906.836626
# 3           0      1.839225      0   799.833810            857.895424
# 4           0      1.531772      0  1283.949061            848.961007
# ...       ...           ...    ...          ...                   ...
# 4995        0      2.391010      0  1557.210762           1146.064082
# 4996        1      0.898693      0  1702.149505           1606.454273
# 4997        0      2.839860      0   965.171368           1701.407359
# 4998        0      1.188440      0  1368.369501           1014.429223
# 4999        0      2.131694      0  1261.301286           1367.627356
#
#       competitor_price_per_kg  marketing_intensity
# 0                    1.935346             0.098677
# 1                    2.344720             0.019318
# 2                    0.998803             0.409485
# 3                    0.761740             0.872803
# 4                    2.123436             0.820779
# ...                       ...                  ...
# 4995                 1.504432             0.756489
# 4996                 1.343586             0.742145
# 4997                 2.771896             0.742145
# 4998                 2.564075             0.742145
# 4999                 0.785727             0.833140
#
# [5000 rows x 11 columns]

# %% [markdown]
# ### Examining Feature-Target Correlations
#
# Before delving into the model building process, it's essential to understand the relationships between our features and the target variable. The upcoming function will display a plot indicating the correlation coefficient for each feature in relation to the target. Here's why this step is crucial:
#
# 1. **Avoiding Data Leakage**: We must ensure that no feature perfectly correlates with the target (a correlation coefficient of 1.0). If such a correlation exists, it's a sign that our dataset might be "leaking" information about the target. Using such data for hyperparameter tuning would mislead the model, as it could easily achieve a perfect score without genuinely learning the underlying patterns.
#
# 2. **Ensuring Meaningful Relationships**: Ideally, our features should have some degree of correlation with the target. If all features have correlation coefficients close to zero, it suggests a weak linear relationship. Although this doesn't automatically render the features useless, it does introduce challenges:
#     * *Predictive Power*: The model might struggle to make accurate predictions.
#     * *Overfitting Risk*: With weak correlations, there's a heightened risk of the model fitting to noise rather than genuine patterns, leading to overfitting.
#     * *Complexity*: Demonstrating non-linear relationships or interactions between features would necessitate more intricate visualizations and evaluations.
# 3. **Auditing and Traceability**: Logging this correlation visualization with our main MLflow run ensures traceability. It provides a snapshot of the data characteristics at the time of the model training, which is invaluable for auditing and replicability purposes.
#
# As we proceed, remember that while understanding correlations is a powerful tool, it's just one piece of the puzzle. Let's visualize these relationships to gain more insights!

# %%
import matplotlib.pyplot as plt
import seaborn as sns


def plot_correlation_with_demand(df, save_path=None):  # noqa: D417
    """
    Plots the correlation of each variable in the dataframe with the 'demand' column.

    Args:
    - df (pd.DataFrame): DataFrame containing the data, including a 'demand' column.
    - save_path (str, optional): Path to save the generated plot. If not specified, plot won't be saved.

    Returns:
    - None (Displays the plot on a Jupyter window)
    """

    # Compute correlations between all variables and 'demand'
    correlations = df.corr()["demand"].drop("demand").sort_values()

    # Generate a color palette from red to green
    colors = sns.diverging_palette(10, 130, as_cmap=True)
    color_mapped = correlations.map(colors)

    # Set Seaborn style
    sns.set_style(
        "whitegrid", {"axes.facecolor": "#c2c4c2", "grid.linewidth": 1.5}
    )  # Light grey background and thicker grid lines

    # Create bar plot
    fig = plt.figure(figsize=(12, 8))
    plt.barh(correlations.index, correlations.values, color=color_mapped)

    # Set labels and title with increased font size
    plt.title("Correlation with Demand", fontsize=18)
    plt.xlabel("Correlation Coefficient", fontsize=16)
    plt.ylabel("Variable", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(axis="x")

    plt.tight_layout()

    # Save the plot if save_path is specified
    if save_path:
        plt.savefig(save_path, format="png", dpi=600)

    # prevent matplotlib from displaying the chart every time we call this function
    plt.close(fig)

    return fig


# Test the function
correlation_plot = plot_correlation_with_demand(df, save_path="correlation_plot.png")

# %% [markdown]
# #### Investigating Feature Correlation with the Target Variable
#
# In the code above, we've intentionally disabled the automatic display of the plot generated by Matplotlib. During machine learning experimentation, it's often not useful to display figures directly within the notebook for several reasons. Instead, we aim to associate this plot with the results of an iterative experiment run. To achieve this, we'll save the plot to our MLflow tracking system. This provides us with a detailed record, linking the state of the dataset to the logged model, its parameters, and performance metrics.
#
# ##### Why Not Display Plots Directly in the Notebook?
#
# Choosing not to display plots within the notebook is a deliberate decision, and the reasons are multiple. Some of the key points include:
#
# - **Ephemerality of Notebooks**: Notebooks are inherently transient; they are not designed to be a permanent record of your work.
#
# - **Risk of Obsolescence**: If you rerun portions of your notebook, the plot displayed could become outdated or misleading, posing a risk when interpreting results.
#
# - **Loss of Previous State**: If you happen to rerun the entire notebook, the plot will be lost. While some plugins can recover previous cell states, setting this up can be cumbersome and time-consuming.
#
# In contrast, logging the plot to MLflow ensures that we have a permanent, easily accessible record that correlates directly with other experiment data. This is invaluable for maintaining the integrity and reproducibility of your machine learning experiments.
#
# ##### Displaying the Plot for This Guide
#
# For the purposes of this guide, we'll still take a moment to examine the plot. We can do this by explicitly calling the figure object we've returned from our function.

# %%
correlation_plot

# %% [markdown]
# #### Visualizing Model Residuals for Diagnostic Insights
#
# The `plot_residuals` function serves to visualize the residuals—the differences between the model's predictions and the actual values in the validation set. Residual plots are crucial diagnostic tools in machine learning, as they can reveal patterns that suggest our model is either failing to capture some aspect of the data or that there's a systematic issue with the model itself.
#
# ##### Why Residual Plots?
#
# Residual plots offer several advantages:
#
# - **Identifying Bias**: If residuals show a trend (not centered around zero), it might indicate that your model is systematically over- or under-predicting the target variable.
#
# - **Heteroskedasticity**: Varying spread of residuals across the range of the predicted values can indicate 'Heteroskedasticity,' which can violate assumptions in some modeling techniques.
#
# - **Outliers**: Points far away from the zero line can be considered as outliers and might warrant further investigation.
#
# ##### Auto-saving the Plot
#
# Just like with the correlation plot, this function allows you to save the residual plot to a specific path. This feature aligns with our broader strategy of logging important figures to MLflow for more effective model tracking and auditing.
#
# ##### Plot Structure
#
# In the scatter plot, each point represents the residual for a specific observation in the validation set. The red horizontal line at zero serves as a reference, indicating where residuals would lie if the model's predictions were perfect.
#
# For the sake of this guide, we will be generating this plot, but not examining it until later when we see it within the MLflow UI.

# %%
def plot_residuals(model, dvalid, valid_y, save_path=None):  # noqa: D417
    """
    Plots the residuals of the model predictions against the true values.

    Args:
    - model: The trained XGBoost model.
    - dvalid (xgb.DMatrix): The validation data in XGBoost DMatrix format.
    - valid_y (pd.Series): The true values for the validation set.
    - save_path (str, optional): Path to save the generated plot. If not specified, plot won't be saved.

    Returns:
    - None (Displays the residuals plot on a Jupyter window)
    """

    # Predict using the model
    preds = model.predict(dvalid)

    # Calculate residuals
    residuals = valid_y - preds

    # Set Seaborn style
    sns.set_style("whitegrid", {"axes.facecolor": "#c2c4c2", "grid.linewidth": 1.5})

    # Create scatter plot
    fig = plt.figure(figsize=(12, 8))
    plt.scatter(valid_y, residuals, color="blue", alpha=0.5)
    plt.axhline(y=0, color="r", linestyle="-")

    # Set labels, title and other plot properties
    plt.title("Residuals vs True Values", fontsize=18)
    plt.xlabel("True Values", fontsize=16)
    plt.ylabel("Residuals", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(axis="y")

    plt.tight_layout()

    # Save the plot if save_path is specified
    if save_path:
        plt.savefig(save_path, format="png", dpi=600)

    # Show the plot
    plt.close(fig)

    return fig

# %% [markdown]
# #### Understanding Feature Importance with XGBoost
#
# The `plot_feature_importance` function is designed to visualize the importance of each feature used in our XGBoost model. Understanding feature importance can offer critical insights into the model's decision-making process and can aid in feature selection, engineering, and interpretation.
#
# ##### Types of Feature Importance
#
# XGBoost offers multiple ways to interpret feature importance. This function supports:
#
# - **Weight**: Number of times a feature appears in a tree across the ensemble of trees (for `gblinear` booster).
# - **Gain**: Average gain (or improvement to the model) of the feature when it is used in trees (for other booster types).
#
# We automatically select the appropriate importance type based on the booster used in the XGBoost model.
#
# ##### Why Feature Importance Matters
#
# Understanding feature importance offers several advantages:
#
# - **Interpretability**: Knowing which features are most influential helps us understand the model better.
# - **Feature Selection**: Unimportant features can potentially be dropped to simplify the model.
# - **Domain Understanding**: Aligns the model's importance scale with domain-specific knowledge or intuition.
#
# ##### Saving and Accessing the Plot
#
# This function returns a Matplotlib figure object that you can further manipulate or save. Like the previous plots, it is advisable to log this plot in MLflow for an immutable record of your model's interpretive characteristics.
#
# ##### Navigating the Plot
#
# In the resulting plot, each bar represents a feature used in the model. The length of the bar corresponds to the feature's importance, as calculated by the selected importance type.
#
# We need a model to be trained in order to generate this plot. As such, we'll be generating, but not displaying the plot when we train the model. The resulting figure will be logged to MLflow and visible within the UI.

# %%
def plot_feature_importance(model, booster):  # noqa: D417
    """
    Plots feature importance for an XGBoost model.

    Args:
    - model: A trained XGBoost model

    Returns:
    - fig: The matplotlib figure object
    """
    fig, ax = plt.subplots(figsize=(10, 8))
    importance_type = "weight" if booster == "gblinear" else "gain"
    xgb.plot_importance(
        model,
        importance_type=importance_type,
        ax=ax,
        title=f"Feature Importance based on {importance_type}",
    )
    plt.tight_layout()
    plt.close(fig)

    return fig

# %% [markdown]
# ### Setting Up the MLflow Experiment
#
# Before we start our hyperparameter tuning process, we need to designate a specific "experiment" within MLflow to track and log our results. An experiment in MLflow is essentially a named set of runs. Each run within an experiment tracks its own parameters, metrics, tags, and artifacts.
#
# #### Why create a new experiment?
#
# 1. **Organization**: It helps in keeping our runs organized under a specific task or project, making it easier to compare and analyze results.
# 2. **Isolation**: By isolating different tasks or projects into separate experiments, we prevent accidental overwrites or misinterpretations of results.
#
# The `get_or_create_experiment` function we've defined below aids in this process. It checks if an experiment with the specified name already exists. If yes, it retrieves its ID. If not, it creates a new experiment and returns its ID.
#
# #### How will we use the experiment_id?
# The retrieved or created experiment_id becomes crucial when we initiate our hyperparameter tuning. As we start the parent run for tuning, the experiment_id ensures that the run, along with its nested child runs, gets logged under the correct experiment. It provides a structured way to navigate, compare, and analyze our tuning results within the MLflow UI.
#
# When we want to try additional parameter ranges, different parameters, or a slightly modified dataset, we can use this Experiment to log all parent runs to keep our MLflow Tracking UI clean and easy to navigate.
#
# Let's proceed and set up our experiment!

# %%
def get_or_create_experiment(experiment_name):
    """
    Retrieve the ID of an existing MLflow experiment or create a new one if it doesn't exist.

    This function checks if an experiment with the given name exists within MLflow.
    If it does, the function returns its ID. If not, it creates a new experiment
    with the provided name and returns its ID.

    Parameters:
    - experiment_name (str): Name of the MLflow experiment.

    Returns:
    - str: ID of the existing or newly created MLflow experiment.
    """

    if experiment := mlflow.get_experiment_by_name(experiment_name):
        return experiment.experiment_id
    else:
        return mlflow.create_experiment(experiment_name)

# %% [markdown]
# #### Create an experiment for our hyperparameter tuning runs

# %%
experiment_id = get_or_create_experiment("Apples Demand")

# %% [markdown]
# We can view the `experiment_id` that was either generated or fetched to see how this unique reference key looks. The value generated here is also visible within the MLflow UI.

# %%
experiment_id
# Out:
# '137375247883971003'

# %% [markdown]
# #### Setting Up MLflow and Data Preprocessing for Model Training
#
# This section of the code accomplishes two major tasks: initializing an MLflow experiment for usage in run tracking and preparing the dataset for model training and validation.
#
# ##### MLflow Initialization
#
# We start by setting the MLflow experiment using the `set_experiment` function. The `experiment_id` serves as a unique identifier for the experiment, allowing us to segregate and manage different runs and their associated data efficiently.
#
# ##### Data Preprocessing
#
# The next steps involve preparing the dataset for model training:
#
# 1. **Feature Selection**: We drop the columns 'date' and 'demand' from our DataFrame, retaining only the feature columns in `X`.
#
# 2. **Target Variable**: The 'demand' column is designated as our target variable `y`.
#
# 3. **Data Splitting**: We split the dataset into training (`train_x`, `train_y`) and validation (`valid_x`, `valid_y`) sets using a 75-25 split.
#
# 4. **XGBoost Data Format**: Finally, we convert the training and validation datasets into XGBoost's DMatrix format. This optimized data structure speeds up the training process and is required for using XGBoost's advanced functionalities.
#
# ##### Why These Steps Matter
#
# - **MLflow Tracking**: Initializing the MLflow experiment ensures that all subsequent model runs, metrics, and artifacts are logged under the same experiment, making it easier to compare and analyze different models. While we are using the ``fluent API`` to do this here, you can also specify the ``experiment_id`` within a ``start_run()`` context.
#
# - **Data Preparation**: Properly preparing your data ensures that the model training process will proceed without issues and that the results will be as accurate as possible.
#
# In the next steps, we'll proceed to model training and evaluation, and all these preparation steps will come into play.

# %%
# Set the current active MLflow experiment
mlflow.set_experiment(experiment_id=experiment_id)

# Preprocess the dataset
X = df.drop(columns=["date", "demand"])
y = df["demand"]
train_x, valid_x, train_y, valid_y = train_test_split(X, y, test_size=0.25)
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(valid_x, label=valid_y)

# %% [markdown]
# #### Hyperparameter Tuning and Model Training using Optuna and MLflow
#
# The `objective` function serves as the core of our hyperparameter tuning process using Optuna. Additionally, it trains an XGBoost model using the selected hyperparameters and logs metrics and parameters to MLflow.
#
# ##### MLflow Nested Runs
#
# The function starts a new nested run in MLflow. Nested runs are useful for organizing hyperparameter tuning experiments as they allow you to group individual runs under a parent run.
#
# ##### Defining Hyperparameters
#
# Optuna's `trial.suggest_*` methods are used to define a range of possible values for hyperparameters. Here's what each hyperparameter does:
#
# - `objective` and `eval_metric`: Define the loss function and evaluation metric.
# - `booster`: Type of boosting to be used (`gbtree`, `gblinear`, or `dart`).
# - `lambda` and `alpha`: Regularization parameters.
# - Additional parameters like `max_depth`, `eta`, and `gamma` are specific to tree-based models (`gbtree` and `dart`).
#
# ##### Model Training
#
# An XGBoost model is trained using the chosen hyperparameters and the preprocessed training dataset (`dtrain`). Predictions are made on the validation set (`dvalid`), and the mean squared error (`mse`) is calculated.
#
# ##### Logging with MLflow
#
# All the selected hyperparameters and metrics (`mse` and `rmse`) are logged to MLflow for later analysis and comparison.
#
# - `mlflow.log_params`: Logs the hyperparameters.
# - `mlflow.log_metric`: Logs the metrics.
#
# ##### Why This Function is Important
#
# - **Automated Tuning**: Optuna automates the process of finding the best hyperparameters.
# - **Experiment Tracking**: MLflow allows us to keep track of each run's hyperparameters and performance metrics, making it easier to analyze, compare, and reproduce experiments later.
#
# In the next step, this objective function will be used by Optuna to find the optimal set of hyperparameters for our XGBoost model.

# %% [markdown]
# #### Housekeeping: Streamlining Logging for Optuna Trials
#
# As we embark on our hyperparameter tuning journey with Optuna, it's essential to understand that the process can generate a multitude of runs. In fact, so many that the standard output (stdout) from the default logger can quickly become inundated, producing pages upon pages of log reports.
#
# While the verbosity of the default logging configuration is undeniably valuable during the code development phase, initiating a full-scale trial can result in an overwhelming amount of information. Considering this, logging every single detail to stdout becomes less practical, especially when we have dedicated tools like MLflow to meticulously track our experiments.
#
# To strike a balance, we'll utilize callbacks to tailor our logging behavior.
#
# ##### Implementing a Logging Callback:
#
# The callback we're about to introduce will modify the default reporting behavior. Instead of logging every trial, we'll only receive updates when a new hyperparameter combination yields an improvement over the best metric value recorded thus far.
#
# This approach offers two salient benefits:
#
# 1. **Enhanced Readability**: By filtering out the extensive log details and focusing only on the trials that show improvement, we can gauge the efficacy of our hyperparameter search. For instance, if we observe a diminishing frequency of 'best result' reports early on, it might suggest that fewer iterations would suffice to pinpoint an optimal hyperparameter set. On the other hand, a consistent rate of improvement might indicate that our feature set requires further refinement.
#
# 2. **Progress Indicators**: Especially pertinent for extensive trials that span hours or even days, receiving periodic updates provides assurance that the process is still in motion. These 'heartbeat' notifications affirm that our system is diligently at work, even if it's not flooding stdout with every minute detail.
#
# Moreover, MLflow's user interface (UI) complements this strategy. As each trial concludes, MLflow logs the child run, making it accessible under the umbrella of the parent run.
#
# In the ensuing code, we:
#
# 1. Adjust Optuna's logging level to report only errors, ensuring a decluttered stdout.
# 2. Define a `champion_callback` function, tailored to log only when a trial surpasses the previously recorded best metric.
#
# Let's dive into the implementation:

# %%
# override Optuna's default logging to ERROR only
optuna.logging.set_verbosity(optuna.logging.ERROR)

# define a logging callback that will report on only new challenger parameter configurations if a
# trial has usurped the state of 'best conditions'


def champion_callback(study, frozen_trial):
    """
    Logging callback that will report when a new trial iteration improves upon existing
    best trial values.

    Note: This callback is not intended for use in distributed computing systems such as Spark
    or Ray due to the micro-batch iterative implementation for distributing trials to a cluster's
    workers or agents.
    The race conditions with file system state management for distributed trials will render
    inconsistent values with this callback.
    """

    winner = study.user_attrs.get("winner", None)

    if study.best_value and winner != study.best_value:
        study.set_user_attr("winner", study.best_value)
        if winner:
            improvement_percent = (abs(winner - study.best_value) / study.best_value) * 100
            print(
                f"Trial {frozen_trial.number} achieved value: {frozen_trial.value} with "
                f"{improvement_percent: .4f}% improvement"
            )
        else:
            print(f"Initial trial {frozen_trial.number} achieved value: {frozen_trial.value}")

# %%
def objective(trial):
    with mlflow.start_run(nested=True):
        # Define hyperparameters
        params = {
            "objective": "reg:squarederror",
            "eval_metric": "rmse",
            "booster": trial.suggest_categorical("booster", ["gbtree", "gblinear", "dart"]),
            "lambda": trial.suggest_float("lambda", 1e-8, 1.0, log=True),
            "alpha": trial.suggest_float("alpha", 1e-8, 1.0, log=True),
        }

        if params["booster"] == "gbtree" or params["booster"] == "dart":
            params["max_depth"] = trial.suggest_int("max_depth", 1, 9)
            params["eta"] = trial.suggest_float("eta", 1e-8, 1.0, log=True)
            params["gamma"] = trial.suggest_float("gamma", 1e-8, 1.0, log=True)
            params["grow_policy"] = trial.suggest_categorical(
                "grow_policy", ["depthwise", "lossguide"]
            )

        # Train XGBoost model
        bst = xgb.train(params, dtrain)
        preds = bst.predict(dvalid)
        error = mean_squared_error(valid_y, preds)

        # Log to MLflow
        mlflow.log_params(params)
        mlflow.log_metric("mse", error)
        mlflow.log_metric("rmse", math.sqrt(error))

    return error

# %% [markdown]
# #### Orchestrating Hyperparameter Tuning, Model Training, and Logging with MLflow
#
# This section of the code serves as the orchestration layer, bringing together Optuna for hyperparameter tuning and MLflow for experiment tracking.
#
# ##### Initiating Parent Run
#
# We begin by starting a parent MLflow run with the name "Best Run". All subsequent operations, including Optuna's trials, are nested under this parent run, providing a structured way to organize our experiments.
#
# ##### Hyperparameter Tuning with Optuna
#
# - `study = optuna.create_study(direction='minimize')`: We create an Optuna study object aiming to minimize our objective function.
# - `study.optimize(objective, n_trials=10)`: The `objective` function is optimized over 10 trials.
#
# ##### Logging Best Parameters and Metrics
#
# After Optuna finds the best hyperparameters, we log these, along with the best mean squared error (`mse`) and root mean squared error (`rmse`), to MLflow.
#
# ##### Logging Additional Metadata
#
# Using `mlflow.set_tags`, we log additional metadata like the project name, optimization engine, model family, and feature set version. This helps in better categorizing and understanding the context of the model run.
#
# ##### Model Training and Artifact Logging
#
# - We train an XGBoost model using the best hyperparameters.
# - Various plots—correlation with demand, feature importance, and residuals—are generated and logged as artifacts in MLflow.
#
# ##### Model Serialization and Logging
#
# Finally, the trained model is logged to MLflow using `mlflow.xgboost.log_model`, along with an example input and additional metadata. The model is stored in a specified artifact path and its URI is retrieved.
#
# ##### Why This Block is Crucial
#
# - **End-to-End Workflow**: This code block represents an end-to-end machine learning workflow, from hyperparameter tuning to model evaluation and logging.
# - **Reproducibility**: All details about the model, including hyperparameters, metrics, and visual diagnostics, are logged, ensuring that the experiment is fully reproducible.
# - **Analysis and Comparison**: With all data logged in MLflow, it becomes easier to analyze the performance of various runs and choose the best model for deployment.
#
# In the next steps, we'll explore how to retrieve and use the logged model for inference.

# %% [markdown]
# #### Setting a Descriptive Name for the Model Run
#
# Before proceeding with model training and hyperparameter tuning, it's beneficial to assign a descriptive name to our MLflow run. This name serves as a human-readable identifier, making it easier to track, compare, and analyze different runs.
#
# ##### The Importance of Naming Runs:
#
# - **Reference by Name**: While MLflow provides unique identifying keys like `run_id` for each run, having a descriptive name allows for more intuitive referencing, especially when using particular APIs and navigating the MLflow UI.
#
# - **Clarity and Context**: A well-chosen run name can provide context about the hypothesis being tested or the specific modifications made, aiding in understanding the purpose and rationale of a particular run.
#
# - **Automatic Naming**: If you don't specify a run name, MLflow will generate a unique fun name for you. However, this might lack the context and clarity of a manually chosen name.
#
# ##### Best Practices:
#
# When naming your runs, consider the following:
#
# 1. **Relevance to Code Changes**: The name should reflect any code or parameter modifications made for that run.
# 2. **Iterative Runs**: If you're executing multiple runs iteratively, it's a good idea to update the run name for each iteration to avoid confusion.
#
# In the subsequent steps, we will set a name for our parent run. Remember, if you execute the model training multiple times, consider updating the run name for clarity.

# %%
run_name = "first_attempt"

# %%
# Initiate the parent run and call the hyperparameter tuning child run logic
with mlflow.start_run(experiment_id=experiment_id, run_name=run_name, nested=True):
    # Initialize the Optuna study
    study = optuna.create_study(direction="minimize")

    # Execute the hyperparameter optimization trials.
    # Note the addition of the `champion_callback` inclusion to control our logging
    study.optimize(objective, n_trials=500, callbacks=[champion_callback])

    mlflow.log_params(study.best_params)
    mlflow.log_metric("best_mse", study.best_value)
    mlflow.log_metric("best_rmse", math.sqrt(study.best_value))

    # Log tags
    mlflow.set_tags(
        tags={
            "project": "Apple Demand Project",
            "optimizer_engine": "optuna",
            "model_family": "xgboost",
            "feature_set_version": 1,
        }
    )

    # Log a fit model instance
    model = xgb.train(study.best_params, dtrain)

    # Log the correlation plot
    mlflow.log_figure(figure=correlation_plot, artifact_file="correlation_plot.png")

    # Log the feature importances plot
    importances = plot_feature_importance(model, booster=study.best_params.get("booster"))
    mlflow.log_figure(figure=importances, artifact_file="feature_importances.png")

    # Log the residuals plot
    residuals = plot_residuals(model, dvalid, valid_y)
    mlflow.log_figure(figure=residuals, artifact_file="residuals.png")

    artifact_path = "model"

    mlflow.xgboost.log_model(
        xgb_model=model,
        artifact_path=artifact_path,
        input_example=train_x.iloc[[0]],
        model_format="ubj",
        metadata={"model_data_version": 1},
    )

    # Get the logged model uri so that we can load it from the artifact store
    model_uri = mlflow.get_artifact_uri(artifact_path)
# Out:
# 🏃 View run intrigued-wolf-886 at: http://localhost:5000/#/experiments/137375247883971003/runs/517d453ad4ca4395855a48fccf66c296
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Initial trial 0 achieved value: 21864.084722006417
# 🏃 View run gifted-stoat-53 at: http://localhost:5000/#/experiments/137375247883971003/runs/6e7acb8baf924e409652fa57e00f9fe0
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run enchanting-slug-967 at: http://localhost:5000/#/experiments/137375247883971003/runs/60d8a7b700be47599897cd2adc3bbf40
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 2 achieved value: 20809.268313868113 with  5.0690% improvement
# 🏃 View run secretive-koi-490 at: http://localhost:5000/#/experiments/137375247883971003/runs/ca3cfa31991f4dd294f42ee5f99d9af9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run exultant-crab-630 at: http://localhost:5000/#/experiments/137375247883971003/runs/50fd2dddead54daf9bb3cbc93238101e
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run victorious-stork-730 at: http://localhost:5000/#/experiments/137375247883971003/runs/705b042ca7be4b94bbf3ab26d00685f1
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run invincible-lark-845 at: http://localhost:5000/#/experiments/137375247883971003/runs/1c3012fa7f654fe48823d2c10b93ca86
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run gaudy-ox-812 at: http://localhost:5000/#/experiments/137375247883971003/runs/e7ad975d892f4200a3a8ab4294867a83
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run wise-stoat-216 at: http://localhost:5000/#/experiments/137375247883971003/runs/2ce39df632224d4b997aef626fd6a0d8
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run magnificent-hog-291 at: http://localhost:5000/#/experiments/137375247883971003/runs/2e779adf700b495e96ffece59bf2289d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 9 achieved value: 20742.7257362327 with  0.3208% improvement
# 🏃 View run bemused-finch-679 at: http://localhost:5000/#/experiments/137375247883971003/runs/8d17edeb651f4f5dbb259b1f9648f8f0
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 10 achieved value: 20517.45112751146 with  1.0980% improvement
# 🏃 View run judicious-shrew-910 at: http://localhost:5000/#/experiments/137375247883971003/runs/0f522f393211428fa7a67f3d6e3f30e1
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run flawless-zebra-621 at: http://localhost:5000/#/experiments/137375247883971003/runs/c249312406194dd1b5f1e5fe58b08e30
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 12 achieved value: 20456.603031605602 with  0.2974% improvement
# 🏃 View run treasured-rat-417 at: http://localhost:5000/#/experiments/137375247883971003/runs/f340bdfbefab4921b3d1419d9416b60f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run clumsy-calf-946 at: http://localhost:5000/#/experiments/137375247883971003/runs/24cbce64917a44009f403195437d85d7
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run traveling-mouse-729 at: http://localhost:5000/#/experiments/137375247883971003/runs/241e66c4f4dc4bc3ad1d23d94c6324d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bedecked-boar-374 at: http://localhost:5000/#/experiments/137375247883971003/runs/c3ebb3991b61410ea15dcb40bc036798
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run calm-vole-441 at: http://localhost:5000/#/experiments/137375247883971003/runs/ae0e7b04013847de854eab297215c861
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run rumbling-loon-315 at: http://localhost:5000/#/experiments/137375247883971003/runs/be0e8e0b085742bab77dc368fa6fa6b4
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 18 achieved value: 15472.165513397402 with  32.2155% improvement
# 🏃 View run burly-sheep-872 at: http://localhost:5000/#/experiments/137375247883971003/runs/2c81da21b39141a58919fee70fff925f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run mercurial-asp-958 at: http://localhost:5000/#/experiments/137375247883971003/runs/7795ff7c5d194f369ac51c7c27d0f098
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 20 achieved value: 15250.93742371209 with  1.4506% improvement
# 🏃 View run grandiose-ape-265 at: http://localhost:5000/#/experiments/137375247883971003/runs/ae700eebeb034fd9991b2bab521b6c4d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run dazzling-ram-995 at: http://localhost:5000/#/experiments/137375247883971003/runs/a402e2cd81e143da952c32d81dad8429
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run charming-shad-827 at: http://localhost:5000/#/experiments/137375247883971003/runs/7e60268226ff42cea3905421fbb742d7
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run nervous-wasp-321 at: http://localhost:5000/#/experiments/137375247883971003/runs/a040fbe12028413b9b8481cf709f54a5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run puzzled-finch-531 at: http://localhost:5000/#/experiments/137375247883971003/runs/74a4e2dedda84ebabd8a8cd39df1b8cd
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run big-lamb-734 at: http://localhost:5000/#/experiments/137375247883971003/runs/75a7f3163dd6457d9c9ed34644e351f4
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 26 achieved value: 14902.07644526173 with  2.3410% improvement
# 🏃 View run languid-mouse-396 at: http://localhost:5000/#/experiments/137375247883971003/runs/d36fc61abbb74727b4e1b7294f0bec3d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run handsome-kit-247 at: http://localhost:5000/#/experiments/137375247883971003/runs/115c8e0161c74776b3204d1cd0bfac97
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run redolent-wasp-701 at: http://localhost:5000/#/experiments/137375247883971003/runs/f8950f6e7a2e45be822826a80fb6b96d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run silent-swan-898 at: http://localhost:5000/#/experiments/137375247883971003/runs/3dc7167b3a294a43b10a79bf158edeb2
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run debonair-yak-784 at: http://localhost:5000/#/experiments/137375247883971003/runs/4a6cb355bb1d4b1da5fcad78e610816f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run burly-goat-427 at: http://localhost:5000/#/experiments/137375247883971003/runs/7727fd0aa3c146359f4ec2fe8f0c7ba5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 32 achieved value: 14817.399629123676 with  0.5715% improvement
# 🏃 View run nebulous-midge-937 at: http://localhost:5000/#/experiments/137375247883971003/runs/061837d21e124310af5a20cedfb278ae
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run rare-stag-101 at: http://localhost:5000/#/experiments/137375247883971003/runs/31f6f187d5d54a67a20bc8e0f65793b8
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run rumbling-sheep-176 at: http://localhost:5000/#/experiments/137375247883971003/runs/139ea759aae84442a9f392eaaa3cbb11
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run peaceful-shrew-444 at: http://localhost:5000/#/experiments/137375247883971003/runs/8e66a56128d746ecb643eb46b4ef4bfe
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run vaunted-finch-944 at: http://localhost:5000/#/experiments/137375247883971003/runs/a6350d4fc8e84e8696eca3f19c2df70f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run nimble-bass-478 at: http://localhost:5000/#/experiments/137375247883971003/runs/031d8f3bf26542c1b4139429d63edf52
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bittersweet-auk-223 at: http://localhost:5000/#/experiments/137375247883971003/runs/a4ac979ccd8c4a6081f69488f5346770
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run angry-eel-294 at: http://localhost:5000/#/experiments/137375247883971003/runs/59298be8ab5a46e2a3a6e070f3fadf58
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run learned-cod-119 at: http://localhost:5000/#/experiments/137375247883971003/runs/940b1c1c8cbc405d9bb31317a543ad3d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bright-hawk-345 at: http://localhost:5000/#/experiments/137375247883971003/runs/089350eb1bc4428d860d1f513ca5db08
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run omniscient-shoat-62 at: http://localhost:5000/#/experiments/137375247883971003/runs/a89db883ffc34badafb89a7b3a69cd04
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run colorful-foal-743 at: http://localhost:5000/#/experiments/137375247883971003/runs/cbbbff53f1654130b6303c935ea68da5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bedecked-koi-934 at: http://localhost:5000/#/experiments/137375247883971003/runs/baa3ac38ab0a4388a7d5e5091b9c06c1
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run thundering-conch-304 at: http://localhost:5000/#/experiments/137375247883971003/runs/d50f5e2cec5741a0b72b7504b283066d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run unique-bear-130 at: http://localhost:5000/#/experiments/137375247883971003/runs/f4b2a8f4381146c2b653a2f157861f93
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run unruly-crab-923 at: http://localhost:5000/#/experiments/137375247883971003/runs/c771f5ba3a06427b908f17b1089258f9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run likeable-finch-435 at: http://localhost:5000/#/experiments/137375247883971003/runs/6e78d7e851d747848b8578b8c6fe4a49
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run dashing-croc-725 at: http://localhost:5000/#/experiments/137375247883971003/runs/077cbece283e4b698463e95613181802
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run gregarious-zebra-672 at: http://localhost:5000/#/experiments/137375247883971003/runs/bf3e3c50de39439090078a7aed752f0d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run spiffy-owl-536 at: http://localhost:5000/#/experiments/137375247883971003/runs/4031d48163af416ca20d8b00ba24ad4a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run delightful-fawn-167 at: http://localhost:5000/#/experiments/137375247883971003/runs/69dbc0deead34fdaa683ab309cc26b89
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run magnificent-tern-410 at: http://localhost:5000/#/experiments/137375247883971003/runs/e383170efeb742ec80a3baafd1fb11a6
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run abrasive-ray-200 at: http://localhost:5000/#/experiments/137375247883971003/runs/083c9cf01b0c4c8d840dd39cf16de490
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run glamorous-chimp-474 at: http://localhost:5000/#/experiments/137375247883971003/runs/da7c6b76196b4629a7ac9da71a7314de
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run wise-squid-676 at: http://localhost:5000/#/experiments/137375247883971003/runs/5f660758d95242ff88675219a22646ba
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run exultant-snail-178 at: http://localhost:5000/#/experiments/137375247883971003/runs/d9728418fa8a4e4dae7fc408849b43d2
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 58 achieved value: 14700.430392133652 with  0.7957% improvement
# 🏃 View run rogue-calf-288 at: http://localhost:5000/#/experiments/137375247883971003/runs/98a8865c9cac4015a8178b6605c0268b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run fearless-newt-523 at: http://localhost:5000/#/experiments/137375247883971003/runs/46ccf19e2fae4483a26a756dc3040060
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run resilient-koi-92 at: http://localhost:5000/#/experiments/137375247883971003/runs/41e16fcc4d4341ac88c9e65d09d2085a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run amusing-mule-695 at: http://localhost:5000/#/experiments/137375247883971003/runs/964fb321f16c4ce39c49590fbe388a2b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run agreeable-fish-385 at: http://localhost:5000/#/experiments/137375247883971003/runs/36688bee2a9145508389513fab0f548f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run industrious-hawk-902 at: http://localhost:5000/#/experiments/137375247883971003/runs/4086ec2482994154ad8adaf750dbcb68
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run overjoyed-slug-326 at: http://localhost:5000/#/experiments/137375247883971003/runs/5fb07fe118e84bb8bafa6b945cc2f1df
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 65 achieved value: 14696.690116392734 with  0.0254% improvement
# 🏃 View run tasteful-moth-496 at: http://localhost:5000/#/experiments/137375247883971003/runs/cf36532f96a544de9cf74c73531a3a0a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run tasteful-ant-922 at: http://localhost:5000/#/experiments/137375247883971003/runs/0177ea435a5a4e04a0c10909d2ce7e8c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run wise-frog-918 at: http://localhost:5000/#/experiments/137375247883971003/runs/9b13bbe34c2240ce944ddcae7a2fbbbc
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run overjoyed-cod-471 at: http://localhost:5000/#/experiments/137375247883971003/runs/678c8d474e004534950f21153c28af65
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 69 achieved value: 14560.065065217259 with  0.9384% improvement
# 🏃 View run secretive-bear-207 at: http://localhost:5000/#/experiments/137375247883971003/runs/3007005244284f909c8b467a96c01e60
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run melodic-conch-609 at: http://localhost:5000/#/experiments/137375247883971003/runs/3d6d7567107943cc9472e0d33f22d61a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run welcoming-snake-327 at: http://localhost:5000/#/experiments/137375247883971003/runs/01a2d849099f487aa1d27802492bd367
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run languid-moose-415 at: http://localhost:5000/#/experiments/137375247883971003/runs/2072f6a6a58c407882ddbb66bd731c5a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run masked-turtle-963 at: http://localhost:5000/#/experiments/137375247883971003/runs/707969fdadf5430c825a2f370fd2709b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run gregarious-hog-767 at: http://localhost:5000/#/experiments/137375247883971003/runs/92aaba9f4aaa410c98c89aba73d89f35
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run judicious-flea-56 at: http://localhost:5000/#/experiments/137375247883971003/runs/217a3bb4ebd54dbeb480e785e526f768
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run judicious-finch-776 at: http://localhost:5000/#/experiments/137375247883971003/runs/9ef79bdc43b44830b167bb028518fb2f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run smiling-shrike-160 at: http://localhost:5000/#/experiments/137375247883971003/runs/471c9769f88c4ea4bc9cf131fb1e053f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run clumsy-shrike-475 at: http://localhost:5000/#/experiments/137375247883971003/runs/b83c5e88d74c40b4a1a06b25bd575b05
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run delightful-skink-825 at: http://localhost:5000/#/experiments/137375247883971003/runs/47e6382acace4409b789941482517cc5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run resilient-cub-33 at: http://localhost:5000/#/experiments/137375247883971003/runs/88a71d4271a0440f9f6925497febbeec
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run whimsical-perch-815 at: http://localhost:5000/#/experiments/137375247883971003/runs/b9bbc77cc5f34d918b64e2169c648c23
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run overjoyed-trout-805 at: http://localhost:5000/#/experiments/137375247883971003/runs/0aacca1fd30f4a65b0635f26f5d558bf
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run languid-hen-127 at: http://localhost:5000/#/experiments/137375247883971003/runs/5b2703ce8c8d4d5b8dde66916c0edba0
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run dapper-croc-598 at: http://localhost:5000/#/experiments/137375247883971003/runs/0c7c0abcc470428fadc557cb65585401
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run rumbling-robin-939 at: http://localhost:5000/#/experiments/137375247883971003/runs/3218a6f04cff492da87c1894577b3a0a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run brawny-dove-136 at: http://localhost:5000/#/experiments/137375247883971003/runs/5b5cffc670ce419881584cb4e5d8bd22
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run valuable-flea-990 at: http://localhost:5000/#/experiments/137375247883971003/runs/2c8b446110cd4796bd33435e24f92172
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run nosy-whale-702 at: http://localhost:5000/#/experiments/137375247883971003/runs/71b212b676f945b987e4170705387ba5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run skillful-stork-989 at: http://localhost:5000/#/experiments/137375247883971003/runs/a0c1ee06706340949b41ce1c6b38bf84
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bright-slug-226 at: http://localhost:5000/#/experiments/137375247883971003/runs/c6ad4394b12243a393c9ef12c054804c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run gifted-skunk-733 at: http://localhost:5000/#/experiments/137375247883971003/runs/215de6025a5545b4a920645a648d53d6
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run glamorous-squirrel-5 at: http://localhost:5000/#/experiments/137375247883971003/runs/569f81bb16424fbd9b2addfb5946b3c6
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run industrious-bear-35 at: http://localhost:5000/#/experiments/137375247883971003/runs/92009756d9a34972b83459e4c89906d9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run glamorous-fish-505 at: http://localhost:5000/#/experiments/137375247883971003/runs/5306e3360a51416984094bb271daa58d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run resilient-gull-16 at: http://localhost:5000/#/experiments/137375247883971003/runs/0d5768f664984e77b1a4baac5dccdec3
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run resilient-toad-206 at: http://localhost:5000/#/experiments/137375247883971003/runs/318534ead30e434786d2b0fc03e04408
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run ambitious-gnat-397 at: http://localhost:5000/#/experiments/137375247883971003/runs/44a444924b914b1294134ebda9193e48
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run stately-jay-535 at: http://localhost:5000/#/experiments/137375247883971003/runs/86ec9ad49caa43e7a8c406288fda0bf5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run skittish-pug-624 at: http://localhost:5000/#/experiments/137375247883971003/runs/caa57690ed35452789ed7ad054df0bf9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run clumsy-flea-574 at: http://localhost:5000/#/experiments/137375247883971003/runs/4a7e279da6a6403480c0da8fc362c5d4
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bright-seal-549 at: http://localhost:5000/#/experiments/137375247883971003/runs/a97419e878d0457bb7865435940c8347
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run magnificent-jay-910 at: http://localhost:5000/#/experiments/137375247883971003/runs/e2763d69ed4a4032871c90288965eda8
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run nebulous-shrimp-668 at: http://localhost:5000/#/experiments/137375247883971003/runs/b78983beef57426ebb22adeb56f011b6
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run redolent-rook-755 at: http://localhost:5000/#/experiments/137375247883971003/runs/394775cecd19442a9fb74a7f4b17fabd
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run amusing-smelt-311 at: http://localhost:5000/#/experiments/137375247883971003/runs/1c763921ad3e43349a0dab04f05ae9b1
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bald-ape-547 at: http://localhost:5000/#/experiments/137375247883971003/runs/c4e77559d1de4d1791c953a69ef983c0
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run kindly-gull-330 at: http://localhost:5000/#/experiments/137375247883971003/runs/8ba51a13473349febbc2930309939d83
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run victorious-sloth-177 at: http://localhost:5000/#/experiments/137375247883971003/runs/a202c27c351e4277a0eaf02c8d81743e
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run enthused-doe-698 at: http://localhost:5000/#/experiments/137375247883971003/runs/4b0f95b140ec47d4a1a37a76e93e3fe5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run gentle-asp-73 at: http://localhost:5000/#/experiments/137375247883971003/runs/0cc31c748e2842908065b1210ce58f32
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 111 achieved value: 14544.587441539019 with  0.1064% improvement
# 🏃 View run angry-gnu-727 at: http://localhost:5000/#/experiments/137375247883971003/runs/ec92597a66324b96ac8d19306d1bb162
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 112 achieved value: 14544.02021990921 with  0.0039% improvement
# 🏃 View run treasured-koi-85 at: http://localhost:5000/#/experiments/137375247883971003/runs/240939f07e2e4000a4a0d916c55ef79e
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run agreeable-skink-634 at: http://localhost:5000/#/experiments/137375247883971003/runs/9b5f4484a1fc42bd8b94892f2ca5813b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run monumental-hen-318 at: http://localhost:5000/#/experiments/137375247883971003/runs/4fd94f7027f549c3b0a6c34956c3015c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run glamorous-pug-658 at: http://localhost:5000/#/experiments/137375247883971003/runs/157ff13063e9462ea62d306f7a4574cc
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run blushing-flea-975 at: http://localhost:5000/#/experiments/137375247883971003/runs/f35492907cfe4d068d89e15e00046c52
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run suave-ape-474 at: http://localhost:5000/#/experiments/137375247883971003/runs/de8fad24f2a34e1b8b72d5818973126c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run abundant-ray-682 at: http://localhost:5000/#/experiments/137375247883971003/runs/a51896c515c14b28aacc0552ba1d376a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run unruly-fish-799 at: http://localhost:5000/#/experiments/137375247883971003/runs/6ec85b88b1d34247acf0538a09463d57
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run wise-koi-438 at: http://localhost:5000/#/experiments/137375247883971003/runs/f391344af9f14bc2b58253ce41aa3997
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run stylish-crab-824 at: http://localhost:5000/#/experiments/137375247883971003/runs/0e8aaf74b59943ca95346ada094f2d62
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# Trial 122 achieved value: 14412.96867957705 with  0.9093% improvement
# 🏃 View run aged-crow-843 at: http://localhost:5000/#/experiments/137375247883971003/runs/3af568def0b346b1a5d23389910b6496
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run suave-ray-447 at: http://localhost:5000/#/experiments/137375247883971003/runs/0725f9b3ca04465b88b8ad3df1741f85
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run sneaky-shark-58 at: http://localhost:5000/#/experiments/137375247883971003/runs/2a8b2604c99e42f981b53318a60943bf
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run melodic-bear-37 at: http://localhost:5000/#/experiments/137375247883971003/runs/6f990d90a4674184a1b014ee48b45ce8
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run abundant-wasp-691 at: http://localhost:5000/#/experiments/137375247883971003/runs/9ee6ca75d65742769c0f7dbf4aaecdcb
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run awesome-frog-818 at: http://localhost:5000/#/experiments/137375247883971003/runs/d8324558cc3346c4ae8a051634a8bf6d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run suave-mole-157 at: http://localhost:5000/#/experiments/137375247883971003/runs/e6ae94d814db4f78b0611e565e5374c9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run legendary-rat-702 at: http://localhost:5000/#/experiments/137375247883971003/runs/d0e3fb24b97a4cf488a0b6c9b8066c73
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run resilient-perch-491 at: http://localhost:5000/#/experiments/137375247883971003/runs/f25251999db84a09ad40b23e2c36b12a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run dapper-sponge-962 at: http://localhost:5000/#/experiments/137375247883971003/runs/fcc7e8d389b84585a614a512c5441391
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run zealous-boar-601 at: http://localhost:5000/#/experiments/137375247883971003/runs/ef6b422ace4f4fb0bcd2da98232e6d95
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run awesome-frog-933 at: http://localhost:5000/#/experiments/137375247883971003/runs/20de001187c14dc1938b854ab236015e
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run luminous-fox-352 at: http://localhost:5000/#/experiments/137375247883971003/runs/8e6139330ac44fbaa7baf845d1d37d34
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run calm-crow-306 at: http://localhost:5000/#/experiments/137375247883971003/runs/1963b3762ecc4f59944e595af04e3c5b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run intrigued-hare-118 at: http://localhost:5000/#/experiments/137375247883971003/runs/f563824fba3049358c94c49b7f3c2d9c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run popular-goat-680 at: http://localhost:5000/#/experiments/137375247883971003/runs/a3aa41efe77e4c69a683c985de9b7908
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run loud-ant-575 at: http://localhost:5000/#/experiments/137375247883971003/runs/1354d03118c04d88a29099b509783e20
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run upbeat-shrike-647 at: http://localhost:5000/#/experiments/137375247883971003/runs/466a9029edba48fc9fbc5ed6c009b77d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run clumsy-foal-861 at: http://localhost:5000/#/experiments/137375247883971003/runs/e31bde1412a3480f843146d7a3200dbd
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bouncy-sheep-937 at: http://localhost:5000/#/experiments/137375247883971003/runs/97de9c6966544ec6a85b722702c547f7
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run efficient-skunk-128 at: http://localhost:5000/#/experiments/137375247883971003/runs/e103a68a769c440398b68bd33a64bdcd
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run peaceful-whale-460 at: http://localhost:5000/#/experiments/137375247883971003/runs/ed46387e6ce34aadafb96215dba5435b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run salty-doe-185 at: http://localhost:5000/#/experiments/137375247883971003/runs/b619e582c1e7453db8706f7a000eb879
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run painted-carp-751 at: http://localhost:5000/#/experiments/137375247883971003/runs/328a315886c24148a758398c87735368
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run silent-newt-398 at: http://localhost:5000/#/experiments/137375247883971003/runs/0d56944d667d48ea84cae9db298f581a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run classy-finch-794 at: http://localhost:5000/#/experiments/137375247883971003/runs/9065e26d987d4f98a1dce5947afbef6e
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run agreeable-snipe-600 at: http://localhost:5000/#/experiments/137375247883971003/runs/0006c942666b48749e0d3aa5dd486841
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bouncy-rook-943 at: http://localhost:5000/#/experiments/137375247883971003/runs/5f311f5b295c4d18b72107fc8af005e6
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run debonair-kit-69 at: http://localhost:5000/#/experiments/137375247883971003/runs/68bd486fe52041518025ccfd8db978d7
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run big-ox-56 at: http://localhost:5000/#/experiments/137375247883971003/runs/10edd941718a415793368dd63d4f2c8d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run puzzled-bee-856 at: http://localhost:5000/#/experiments/137375247883971003/runs/c91a73da49fb4999895fa91d66a1f219
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run judicious-cod-47 at: http://localhost:5000/#/experiments/137375247883971003/runs/7e87e508e34a4312b0d2af5b9d84de86
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bittersweet-mink-631 at: http://localhost:5000/#/experiments/137375247883971003/runs/dd2334767b3f4738888990c34d49bc22
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run dazzling-mouse-818 at: http://localhost:5000/#/experiments/137375247883971003/runs/757dd863cfc846bfb55d9d46fabbedaa
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run thoughtful-chimp-142 at: http://localhost:5000/#/experiments/137375247883971003/runs/1ac8073ee7e347188ae6586c52f2bee0
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bittersweet-hen-452 at: http://localhost:5000/#/experiments/137375247883971003/runs/6b22835a4de44d0894bac3a5d484d430
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run lyrical-smelt-647 at: http://localhost:5000/#/experiments/137375247883971003/runs/c2f776f165654c099c5f60ea12a65746
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run spiffy-swan-436 at: http://localhost:5000/#/experiments/137375247883971003/runs/098075b08d44493f96cae7a14f238af9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run thundering-goat-889 at: http://localhost:5000/#/experiments/137375247883971003/runs/e8a48d60ab684fdaa04de5d250edfe0c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run abundant-skink-162 at: http://localhost:5000/#/experiments/137375247883971003/runs/ffc7da3ea519457c95f0320969e22ea2
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bald-panda-311 at: http://localhost:5000/#/experiments/137375247883971003/runs/89b78eb5a17442539cc88d1f2f4381c5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run welcoming-bird-612 at: http://localhost:5000/#/experiments/137375247883971003/runs/c154469cc73a4be9870db7d1f2f81a23
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run shivering-bass-668 at: http://localhost:5000/#/experiments/137375247883971003/runs/2724ae8608494f95982a3fec2d43c2b3
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bemused-shoat-757 at: http://localhost:5000/#/experiments/137375247883971003/runs/fb83e849d2cc498ca6ec1d1131d21d67
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run monumental-calf-799 at: http://localhost:5000/#/experiments/137375247883971003/runs/80c67996449a4de39700e3d7f9f589fb
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run able-crane-655 at: http://localhost:5000/#/experiments/137375247883971003/runs/a12f23fa7ef24a56b53d8740a5605ae5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run redolent-goat-866 at: http://localhost:5000/#/experiments/137375247883971003/runs/0e8db870f3e8420e8cddcada96e299ff
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run gaudy-fawn-863 at: http://localhost:5000/#/experiments/137375247883971003/runs/b16c257bb64047fb9c430e277ab725be
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run brawny-rat-430 at: http://localhost:5000/#/experiments/137375247883971003/runs/0ae90720232542008f0214424dc69709
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run handsome-owl-517 at: http://localhost:5000/#/experiments/137375247883971003/runs/5ea7aa0917254e4c862f23da275eebeb
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run inquisitive-bug-221 at: http://localhost:5000/#/experiments/137375247883971003/runs/edc6071bca374304b15cf7dc1a82ae3b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run chill-cub-133 at: http://localhost:5000/#/experiments/137375247883971003/runs/f913db17e12048eca211c6e5311958b9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run suave-croc-531 at: http://localhost:5000/#/experiments/137375247883971003/runs/d0ccb19a5b0547498adde255fda431ab
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run unleashed-bug-840 at: http://localhost:5000/#/experiments/137375247883971003/runs/0d9c932290ea4a9181c2a6200dadbab9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run mysterious-wren-382 at: http://localhost:5000/#/experiments/137375247883971003/runs/d665b0419d8b40e691358bfd3125c580
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run mysterious-panda-368 at: http://localhost:5000/#/experiments/137375247883971003/runs/0b248574588444999d734212d14d4be3
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run dapper-kit-308 at: http://localhost:5000/#/experiments/137375247883971003/runs/5a8b03de13704e5bac4a33c5230cf04c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run intrigued-rat-717 at: http://localhost:5000/#/experiments/137375247883971003/runs/45bb84cbbaf24a668efc4b63f1a40407
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bittersweet-bat-285 at: http://localhost:5000/#/experiments/137375247883971003/runs/0177b29060ea4853a980baf77b20c251
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run glamorous-bear-956 at: http://localhost:5000/#/experiments/137375247883971003/runs/aec982ba1cb34acfa496bc5de3581b0a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run popular-loon-496 at: http://localhost:5000/#/experiments/137375247883971003/runs/0342902b119a4a769ca65ba11667f525
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run flawless-squirrel-9 at: http://localhost:5000/#/experiments/137375247883971003/runs/d11c0119744f404298118956f3fcbf01
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run abrasive-mare-663 at: http://localhost:5000/#/experiments/137375247883971003/runs/c880549ae08248fbb64218446e403fae
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run thoughtful-dove-745 at: http://localhost:5000/#/experiments/137375247883971003/runs/69697e22c9a949a09189c8b06151cd0e
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bright-snake-458 at: http://localhost:5000/#/experiments/137375247883971003/runs/ef2439b9106245638ea587aa8dbf8d99
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run capable-conch-515 at: http://localhost:5000/#/experiments/137375247883971003/runs/d0c623fdbe1149c4a0593164803efab2
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run upbeat-stag-488 at: http://localhost:5000/#/experiments/137375247883971003/runs/6403a0fcafc54e8e8c0b624f0c2c50bb
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run exultant-bear-994 at: http://localhost:5000/#/experiments/137375247883971003/runs/635785508f8346bda72e3c75609373a9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run useful-cub-180 at: http://localhost:5000/#/experiments/137375247883971003/runs/7e0bea3d07dd4c939bc27cc5a34200cd
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run secretive-ant-276 at: http://localhost:5000/#/experiments/137375247883971003/runs/5065206c2b2e4dbe9301177e12007271
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run upbeat-shrimp-895 at: http://localhost:5000/#/experiments/137375247883971003/runs/c0f37bde02f245df93d2d72a8da9e917
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run serious-bat-38 at: http://localhost:5000/#/experiments/137375247883971003/runs/b49dfcda950144dcb666357270e27ee2
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run chill-croc-336 at: http://localhost:5000/#/experiments/137375247883971003/runs/e538752f3b174742b3c0622fc04905f5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run indecisive-roo-192 at: http://localhost:5000/#/experiments/137375247883971003/runs/7a8f338556664020874a468929d46361
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bustling-crow-364 at: http://localhost:5000/#/experiments/137375247883971003/runs/0a4dfb2fe28e48b992e7b8d94dc627cf
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run marvelous-cod-65 at: http://localhost:5000/#/experiments/137375247883971003/runs/6de31cc9197e4468b8b8e15956b091cf
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run smiling-fox-409 at: http://localhost:5000/#/experiments/137375247883971003/runs/12590415fd394beab3abf47c011e06d1
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run delicate-toad-833 at: http://localhost:5000/#/experiments/137375247883971003/runs/d9c530f2dd5344e6a108939dd6e9cf2d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run chill-doe-575 at: http://localhost:5000/#/experiments/137375247883971003/runs/84376d9a86d5488e8931f4780c3d173c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run judicious-flea-690 at: http://localhost:5000/#/experiments/137375247883971003/runs/6671c9b9e6c24c8986bf976599f657bb
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run mysterious-shad-713 at: http://localhost:5000/#/experiments/137375247883971003/runs/324fd932e54441fd802c38b8a180c4a2
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run thoughtful-tern-33 at: http://localhost:5000/#/experiments/137375247883971003/runs/d0d078727d454246b7884b7b8ca32c0a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bold-sloth-314 at: http://localhost:5000/#/experiments/137375247883971003/runs/f9259e05e6f645deaa485b7f972ab44a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run kindly-dove-290 at: http://localhost:5000/#/experiments/137375247883971003/runs/743e6e842be7401f8a21fb5ce19cfd5c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run salty-mouse-282 at: http://localhost:5000/#/experiments/137375247883971003/runs/6f77bf72f86f4aafac0af9bd38f4b0d9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run luxuriant-owl-592 at: http://localhost:5000/#/experiments/137375247883971003/runs/74d99270913a49a0bd8b75ed7dd243c6
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run painted-lamb-777 at: http://localhost:5000/#/experiments/137375247883971003/runs/92ea628d80af481bb19749620602deaa
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run skittish-koi-676 at: http://localhost:5000/#/experiments/137375247883971003/runs/dafba17036694f40abf21f274c43b6d6
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run vaunted-cub-814 at: http://localhost:5000/#/experiments/137375247883971003/runs/c46f1cec8f55464d954a8d34f16680e8
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run melodic-gull-995 at: http://localhost:5000/#/experiments/137375247883971003/runs/4a72e65bcd19422ca2768e2da4f67146
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run likeable-seal-643 at: http://localhost:5000/#/experiments/137375247883971003/runs/181315e1b2714a838e03d52519293747
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run abrasive-rook-134 at: http://localhost:5000/#/experiments/137375247883971003/runs/23081473afc14b82a9b363b1b35c032f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run hilarious-shark-355 at: http://localhost:5000/#/experiments/137375247883971003/runs/4533b697fa7d471babd51662f39a242d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run painted-moose-987 at: http://localhost:5000/#/experiments/137375247883971003/runs/1cf6526d2a3a495bb0638a94603d3718
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run delightful-mouse-246 at: http://localhost:5000/#/experiments/137375247883971003/runs/970b4a71587c4eccaccf85d90dd02610
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run welcoming-newt-327 at: http://localhost:5000/#/experiments/137375247883971003/runs/275f3e7171dd420b9c5eaad141e4a13f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run skittish-asp-693 at: http://localhost:5000/#/experiments/137375247883971003/runs/6d2f3989ddf544a3ab6645f362272783
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run adaptable-trout-345 at: http://localhost:5000/#/experiments/137375247883971003/runs/a802e564885a4d439d17657ccf51bcf1
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run righteous-snake-690 at: http://localhost:5000/#/experiments/137375247883971003/runs/1bc17a5e18d34bf9b17531e1704b6fa3
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run shivering-donkey-413 at: http://localhost:5000/#/experiments/137375247883971003/runs/4567b858980d4c7c9db05560f48cf09f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run calm-finch-227 at: http://localhost:5000/#/experiments/137375247883971003/runs/b1a292fe00754c22bdf76ff41ac41a86
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bemused-wren-578 at: http://localhost:5000/#/experiments/137375247883971003/runs/0dea2ab77500457c887c3b4f4fe4c9a0
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run marvelous-stoat-163 at: http://localhost:5000/#/experiments/137375247883971003/runs/16b139a69345422a8a00f04310bf2982
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run unique-snipe-442 at: http://localhost:5000/#/experiments/137375247883971003/runs/3c120965cd1d4934978ccefaa563e9e9
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run fun-crow-371 at: http://localhost:5000/#/experiments/137375247883971003/runs/15996f44f7e24ad1beca4c6b3bb0ec80
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run unleashed-deer-655 at: http://localhost:5000/#/experiments/137375247883971003/runs/f4eea3becbfc49019b4fd6d7a996e892
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bedecked-jay-740 at: http://localhost:5000/#/experiments/137375247883971003/runs/31f72d1b97634bd6bec217e9e2bdaba8
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run ambitious-shrimp-144 at: http://localhost:5000/#/experiments/137375247883971003/runs/6584dfacccc54fbcb0ade0db7e1c1b67
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run aged-pig-8 at: http://localhost:5000/#/experiments/137375247883971003/runs/318fccbae1e042bf854939349f183d26
# ...
# 🏃 View run capricious-panda-482 at: http://localhost:5000/#/experiments/137375247883971003/runs/1af14067a27a4e7e8219ce311a0b207f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run nervous-mouse-944 at: http://localhost:5000/#/experiments/137375247883971003/runs/62c7ca4057ee4fbbbd4703698361df02
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run lyrical-wren-496 at: http://localhost:5000/#/experiments/137375247883971003/runs/c42e4e3df0714d3592ef51e2330abf7a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run worried-owl-942 at: http://localhost:5000/#/experiments/137375247883971003/runs/7e49b7a33f4d41ebb2d603af1f5586fc
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run luxuriant-croc-572 at: http://localhost:5000/#/experiments/137375247883971003/runs/604cd783b18e4869bd3e5bebc2a26884
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run painted-panda-438 at: http://localhost:5000/#/experiments/137375247883971003/runs/19e78f5e215d4d0cac8a01f458e454bb
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run clean-lamb-283 at: http://localhost:5000/#/experiments/137375247883971003/runs/4b0ab4a72fcf451a93177fd54bcb7ebd
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run nimble-penguin-106 at: http://localhost:5000/#/experiments/137375247883971003/runs/38e176b62d114022a8648843ccc527fa
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bustling-pig-695 at: http://localhost:5000/#/experiments/137375247883971003/runs/df52ce12bbf4491892b54ecf14dbb17c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run redolent-ram-965 at: http://localhost:5000/#/experiments/137375247883971003/runs/539bf687aaae421c8653002f86f92a31
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run funny-gull-540 at: http://localhost:5000/#/experiments/137375247883971003/runs/6f1e8282541c4761a44d7b1b91692894
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run powerful-sheep-871 at: http://localhost:5000/#/experiments/137375247883971003/runs/a516c90e2ffc4d23b64e81b8fb3a2f5f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run clean-donkey-871 at: http://localhost:5000/#/experiments/137375247883971003/runs/8dfc691dc89c49389c68133f7a970781
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run stately-shrew-866 at: http://localhost:5000/#/experiments/137375247883971003/runs/1168dd255a114faf927aad08a12bca50
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run gifted-koi-596 at: http://localhost:5000/#/experiments/137375247883971003/runs/0af29b3a0dab4bd996e4b3ed0e901be6
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run funny-bird-503 at: http://localhost:5000/#/experiments/137375247883971003/runs/d5ef041cd01643e091be9239a3dfae9b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run enchanting-bear-588 at: http://localhost:5000/#/experiments/137375247883971003/runs/8beab74aba8141cea45ac229b1823de5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run big-grouse-672 at: http://localhost:5000/#/experiments/137375247883971003/runs/d00b1f684522468998e4aa764eb625d3
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run selective-grub-236 at: http://localhost:5000/#/experiments/137375247883971003/runs/3e5ec4e46db9467287a77ccda849f9ed
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run thundering-vole-596 at: http://localhost:5000/#/experiments/137375247883971003/runs/f9a7e3f2d16f43bb93cf73ae9c340721
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run amusing-crab-836 at: http://localhost:5000/#/experiments/137375247883971003/runs/bc02b13c52804ff8a4c6c96c77d0061d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run clean-calf-571 at: http://localhost:5000/#/experiments/137375247883971003/runs/7ab3ca0ab26f41b8adad76be9f8e11e3
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run unruly-bass-577 at: http://localhost:5000/#/experiments/137375247883971003/runs/5f3ab1ec52424e9bbdf7ef6f6ab25f09
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run nebulous-yak-831 at: http://localhost:5000/#/experiments/137375247883971003/runs/7d8e0c29182b4597994db6d79b7df778
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run illustrious-calf-598 at: http://localhost:5000/#/experiments/137375247883971003/runs/2abeb0434b734d4b9f78c172dbc94efe
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run defiant-gnu-998 at: http://localhost:5000/#/experiments/137375247883971003/runs/14608a36457249a199c0b0f5bdf901f3
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run zealous-bird-972 at: http://localhost:5000/#/experiments/137375247883971003/runs/32526cf0de0644b2bd5f35215f025490
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run mysterious-duck-495 at: http://localhost:5000/#/experiments/137375247883971003/runs/d13c17528ba34c8693beb750f5e7b3a8
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run whimsical-whale-233 at: http://localhost:5000/#/experiments/137375247883971003/runs/f840c759b40e49e7b0c2d4e2cf391ce5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bustling-tern-478 at: http://localhost:5000/#/experiments/137375247883971003/runs/6d687814bfae4787a1f09f6f2df2e7a5
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run nosy-dove-990 at: http://localhost:5000/#/experiments/137375247883971003/runs/c8fdcce1deed44e188da50649f2d2310
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run resilient-whale-685 at: http://localhost:5000/#/experiments/137375247883971003/runs/f07064994a8f48eb94f3ff96ea51b2fc
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run languid-seal-758 at: http://localhost:5000/#/experiments/137375247883971003/runs/67203a90957d49f4bac446b657b65da2
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bold-swan-171 at: http://localhost:5000/#/experiments/137375247883971003/runs/6a9af6fb2b1d4f7b8145802cf93d6b4a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run redolent-snipe-647 at: http://localhost:5000/#/experiments/137375247883971003/runs/444b696239c14f2d9b9e3cc5f2bbef4a
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run upset-mole-145 at: http://localhost:5000/#/experiments/137375247883971003/runs/ed7410bcc6a04508ba49ff7f6e2a90d2
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run tasteful-wren-503 at: http://localhost:5000/#/experiments/137375247883971003/runs/e3d9ae85ee6d400d85dbe8f696d7087f
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run peaceful-lark-753 at: http://localhost:5000/#/experiments/137375247883971003/runs/20044622e4ad4e4d9373f39a1bd71e24
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run useful-finch-694 at: http://localhost:5000/#/experiments/137375247883971003/runs/25f52b203d4a4eef9742cd210e02b48c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run orderly-asp-164 at: http://localhost:5000/#/experiments/137375247883971003/runs/cdf299fc5b5e40c6b7e2fa1ba0b9b61d
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run intrigued-roo-376 at: http://localhost:5000/#/experiments/137375247883971003/runs/5daa70042aca4c4e8ee24874e21553d6
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run whimsical-slug-980 at: http://localhost:5000/#/experiments/137375247883971003/runs/4d07bdb00e734260a706d3e3e7187e18
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run whimsical-tern-311 at: http://localhost:5000/#/experiments/137375247883971003/runs/b1806a0a1e424d0995259b666cd4758e
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run gifted-cat-621 at: http://localhost:5000/#/experiments/137375247883971003/runs/1a2a69e530c34c4f8d67a435ad01cbb1
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bedecked-shrimp-501 at: http://localhost:5000/#/experiments/137375247883971003/runs/226feb1174184b009f30739bba9502f4
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run traveling-skunk-193 at: http://localhost:5000/#/experiments/137375247883971003/runs/4338f03ff471416dbe1a64fb04b9996e
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run carefree-shrimp-834 at: http://localhost:5000/#/experiments/137375247883971003/runs/e45c702707624a14b730ca110a3f52bd
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run gifted-rat-521 at: http://localhost:5000/#/experiments/137375247883971003/runs/1151616c15a84e118f272fe3175018d3
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run clumsy-chimp-981 at: http://localhost:5000/#/experiments/137375247883971003/runs/bcac83b084a1492bbf3b93f31071fdf4
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run nebulous-fowl-936 at: http://localhost:5000/#/experiments/137375247883971003/runs/4964bffcc862475abcb0ac5a2aa9ecdb
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run adorable-quail-899 at: http://localhost:5000/#/experiments/137375247883971003/runs/ffa67e5a65284566a1a83b0eba6b9417
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run monumental-carp-150 at: http://localhost:5000/#/experiments/137375247883971003/runs/0fbf1788eb6c4846bc5614bc4c436ed0
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run amazing-mole-108 at: http://localhost:5000/#/experiments/137375247883971003/runs/ad1a720936d642ef8c0557124683927c
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run ambitious-slug-162 at: http://localhost:5000/#/experiments/137375247883971003/runs/83623842edce4eeb9f5f1134cf5241d3
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run mercurial-vole-804 at: http://localhost:5000/#/experiments/137375247883971003/runs/d546b5c2b2f94fb8acf8c5707ab5994b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run clean-stag-67 at: http://localhost:5000/#/experiments/137375247883971003/runs/32cddf32c5034c71a74bb25d1d5014de
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run unequaled-worm-792 at: http://localhost:5000/#/experiments/137375247883971003/runs/bce1bb9d6b314b2f83aa49048c0c80f7
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run welcoming-wren-191 at: http://localhost:5000/#/experiments/137375247883971003/runs/9fa543cf9c394f34be6e4c832d7fa451
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run melodic-mouse-672 at: http://localhost:5000/#/experiments/137375247883971003/runs/5081e431438447f1a970e1e87b99dfe0
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run dashing-mole-696 at: http://localhost:5000/#/experiments/137375247883971003/runs/f9e925f3e7b34d8082877520d1b01a8b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run upset-zebra-557 at: http://localhost:5000/#/experiments/137375247883971003/runs/1b402b06eed94779b8d5d0bafb0b55c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run flawless-fawn-51 at: http://localhost:5000/#/experiments/137375247883971003/runs/c6b6f9dd84f849de94bc5e8b1ca5c5c7
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run burly-shrimp-998 at: http://localhost:5000/#/experiments/137375247883971003/runs/7aa53d6be12442318971781d5d2a1633
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run judicious-midge-994 at: http://localhost:5000/#/experiments/137375247883971003/runs/210753ba7eb84ff0a5ce9772514bf9e3
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run nosy-finch-973 at: http://localhost:5000/#/experiments/137375247883971003/runs/1ae8b75dbb4d4bc3acd4c594df5eee50
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run rumbling-finch-234 at: http://localhost:5000/#/experiments/137375247883971003/runs/df0c6a627ec44692a4736734777a522b
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run chill-horse-244 at: http://localhost:5000/#/experiments/137375247883971003/runs/0665d223ac6d4546b24cc3b991e58574
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run monumental-fowl-326 at: http://localhost:5000/#/experiments/137375247883971003/runs/2b21853e805649209eebcc59ba7fa5fd
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run dapper-loon-689 at: http://localhost:5000/#/experiments/137375247883971003/runs/b3886f6230f84a3bba0d12d4ad2f2d46
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run amazing-mare-403 at: http://localhost:5000/#/experiments/137375247883971003/runs/a5f0c43532154587995365d6b53070ac
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run shivering-mouse-678 at: http://localhost:5000/#/experiments/137375247883971003/runs/e7ae8a80a4664343b71271405ee737d4
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run marvelous-panda-640 at: http://localhost:5000/#/experiments/137375247883971003/runs/c15faac6fba9407d8c14f66f0e1bee05
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# 🏃 View run bold-hog-263 at: http://localhost:5000/#/experiments/137375247883971003/runs/942ba01c89ca45f0bfed16ddd6c614ab
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003
# /home/dave/Documents/projects/mlflow_optuna/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:407: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2024/11/20 20:27:37 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run first_attempt at: http://localhost:5000/#/experiments/137375247883971003/runs/409b5a30197540bd8cbbd42047444b2e
# 🧪 View experiment at: http://localhost:5000/#/experiments/137375247883971003

# %% [markdown]
# #### Understanding the Artifact URI in MLflow
#
# The output 'mlflow-artifacts:/908436739760555869/c8d64ce51f754eb698a3c09239bcdcee/artifacts/model' represents a unique Uniform Resource Identifier (URI) for the trained model artifacts within MLflow. This URI is a crucial component of MLflow's architecture, and here's why:
#
# ##### Simplified Access to Model Artifacts
#
# The `model_uri` abstracts away the underlying storage details, providing a consistent and straightforward way to reference model artifacts, regardless of where they are stored. Whether your artifacts are on a local filesystem, in a cloud storage bucket, or on a network mount, the URI remains a consistent reference point.
#
# ##### Abstraction of Storage Details
#
# MLflow is designed to be storage-agnostic. This means that while you might switch the backend storage from, say, a local directory to an Amazon S3 bucket, the way you interact with MLflow remains consistent. The URI ensures that you don't need to know the specifics of the storage backend; you only need to reference the model's URI.
#
# ##### Associated Information and Metadata
#
# Beyond just the model files, the URI provides access to associated metadata, the model artifact, and other logged artifacts (files and images). This ensures that you have a comprehensive set of information about the model, aiding in reproducibility, analysis, and deployment.
#
# ##### In Summary
#
# The `model_uri` serves as a consistent, abstracted reference to your model and its associated data. It simplifies interactions with MLflow, ensuring that users don't need to worry about the specifics of underlying storage mechanisms and can focus on the machine learning workflow.

# %%
model_uri
# Out:
# 'mlflow-artifacts:/908436739760555869/c28196b19e1843bca7e22f07d796e740/artifacts/model'

# %% [markdown]
# #### Loading the Trained Model with MLflow
#
# With the line:
#
# ```python
# loaded = mlflow.xgboost.load_model(model_uri)
# ```
# we're leveraging MLflow's native model loader for XGBoost. Instead of using the generic pyfunc loader, which provides a universal Python function interface for models, we're using the XGBoost-specific loader.
#
# ##### Benefits of Native Loading:
#
# - **Fidelity**: Loading the model using the native loader ensures that you're working with the exact same model object as it was during training. This means all nuances, specifics, and intricacies of the original model are preserved.
#
# - **Functionality**: With the native model object in hand, you can utilize all of its inherent methods and properties. This allows for more flexibility, especially when you need advanced features or fine-grained control during inference.
#
# - **Performance**: Using the native model object might offer performance benefits, especially when performing batch inference or deploying the model in environments optimized for the specific machine learning framework.
#
# In essence, by loading the model natively, we ensure maximum compatibility and functionality, allowing for a seamless transition from training to inference.

# %%
loaded = mlflow.xgboost.load_model(model_uri)
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# #### Example: Batch Inference Using the Loaded Model
#
# After loading the model natively, performing batch inference is straightforward.
#
# In the following cell, we're going to perform a prediction based on the entire source feature set.
# Although doing an inference action on the entire training and validation dataset features is of very limited utility in a real-world application, we'll use our generated synthetic data here to illustrate using the native model for inference.

# %% [markdown]
# #### Performing Batch Inference and Augmenting Data
#
# In this section, we're taking our entire dataset and performing batch inference using our loaded XGBoost model. We'll then append these predictions back into our original dataset to compare, analyze, or further process.
#
# ##### Steps Explained:
#
# 1. **Creating a DMatrix**: `batch_dmatrix = xgb.DMatrix(X)`: We first convert our features (`X`) into XGBoost's optimized DMatrix format. This data structure is specifically designed for efficiency and speed in XGBoost.
#
# 2. **Predictions**: `inference = loaded.predict(batch_dmatrix)`: Using the previously loaded model (`loaded`), we perform batch inference on the entire dataset.
#
# 3. **Creating a New DataFrame**: `infer_df = df.copy()`: We create a copy of the original DataFrame to ensure that we're not modifying our original data.
#
# 4. **Appending Predictions**: `infer_df["predicted_demand"] = inference`: The predictions are then added as a new column, `predicted_demand`, to this DataFrame.
#
# ##### Best Practices:
#
# - **Always Copy Data**: When augmenting or modifying datasets, it's generally a good idea to work with a copy. This ensures that the original data remains unchanged, preserving data integrity.
#
# - **Batch Inference**: When predicting on large datasets, using batch inference (as opposed to individual predictions) can offer significant speed improvements.
#
# - **DMatrix Conversion**: While converting to DMatrix might seem like an extra step, it's crucial for performance when working with XGBoost. It ensures that predictions are made as quickly as possible.
#
# In the subsequent steps, we can further analyze the differences between the actual demand and our model's predicted demand, potentially visualizing the results or calculating performance metrics.

# %%
batch_dmatrix = xgb.DMatrix(X)

inference = loaded.predict(batch_dmatrix)

infer_df = df.copy()

infer_df["predicted_demand"] = inference

# %% [markdown]
# #### Visualizing the Augmented DataFrame
#
# Below, we display the `infer_df` DataFrame. This augmented dataset now includes both the actual demand (`demand`) and the model's predictions (`predicted_demand`). By examining this table, we can get a quick sense of how well our model's predictions align with the actual demand values.

# %%
infer_df
# Out:
#                            date  average_temperature   rainfall  weekend  \
# 0    2011-03-15 19:14:17.796487            30.584727   1.199291        0
# 1    2011-03-16 19:14:17.796486            15.465069   1.037626        0
# 2    2011-03-17 19:14:17.796486            10.786525   5.656089        0
# 3    2011-03-18 19:14:17.796485            23.648154  12.030937        0
# 4    2011-03-19 19:14:17.796484            13.861391   4.303812        1
# ...                         ...                  ...        ...      ...
# 4995 2024-11-16 19:14:17.793289            21.643051   3.821656        1
# 4996 2024-11-17 19:14:17.793288            13.808813   1.080603        1
# 4997 2024-11-18 19:14:17.793288            11.698227   1.911000        0
# 4998 2024-11-19 19:14:17.793286            18.052081   1.000521        0
# 4999 2024-11-20 19:14:17.793282            17.017294   0.650213        0
#
#       holiday  price_per_kg  promo       demand  previous_days_demand  \
# 0           0      1.726258      0   851.375336            851.276659
# 1           0      0.576471      0   906.855943            851.276659
# 2           0      2.513328      0   808.304909            906.836626
# 3           0      1.839225      0   799.833810            857.895424
# 4           0      1.531772      0  1283.949061            848.961007
# ...       ...           ...    ...          ...                   ...
# 4995        0      2.391010      0  1557.210762           1146.064082
# 4996        1      0.898693      0  1702.149505           1606.454273
# 4997        0      2.839860      0   965.171368           1701.407359
# 4998        0      1.188440      0  1368.369501           1014.429223
# 4999        0      2.131694      0  1261.301286           1367.627356
#
#       competitor_price_per_kg  marketing_intensity  predicted_demand
# 0                    1.935346             0.098677        925.953430
# 1                    2.344720             0.019318        982.542969
# 2                    0.998803             0.409485        859.387695
# 3                    0.761740             0.872803        918.754089
# 4                    2.123436             0.820779       1296.207520
# ...                       ...                  ...               ...
# 4995                 1.504432             0.756489       1335.906616
# 4996                 1.343586             0.742145       1615.351074
# 4997                 2.771896             0.742145       1121.415039
# 4998                 2.564075             0.742145       1057.727051
# 4999                 0.785727             0.833140       1065.559814
#
# [5000 rows x 12 columns]

# %% [markdown]
# #### Wrapping Up: Reflecting on Our Comprehensive Machine Learning Workflow
#
# Throughout this guide, we embarked on a detailed exploration of an end-to-end machine learning workflow. We began with data preprocessing, delved deeply into hyperparameter tuning with Optuna, leveraged MLflow for structured experiment tracking, and concluded with batch inference.
#
# ##### Key Takeaways:
#
# - **Hyperparameter Tuning with Optuna**: We harnessed the power of Optuna to systematically search for the best hyperparameters for our XGBoost model, aiming to optimize its performance.
#
# - **Structured Experiment Tracking with MLflow**: MLflow's capabilities shone through as we logged experiments, metrics, parameters, and artifacts. We also explored the benefits of nested child runs, allowing us to logically group and structure our experiment iterations.
#
# - **Model Interpretation**: Various plots and metrics equipped us with insights into our model's behavior. We learned to appreciate its strengths and identify potential areas for refinement.
#
# - **Batch Inference**: The nuances of batch predictions on extensive datasets were explored, alongside methods to seamlessly integrate these predictions back into our primary data.
#
# - **Logging Visual Artifacts**: A significant portion of our journey emphasized the importance of logging visual artifacts, like plots, to MLflow. These visuals serve as invaluable references, capturing the state of the model, its performance, and any alterations to the feature set that might sway the model's performance metrics.
#
# By the end of this guide, you should possess a robust understanding of a well-structured machine learning workflow. This foundation not only empowers you to craft effective models but also ensures that each step, from data wrangling to predictions, is transparent, reproducible, and efficient.
#
# We're grateful you accompanied us on this comprehensive journey. The practices and insights gleaned will undoubtedly be pivotal in all your future machine learning endeavors!
